# %% [markdown]
# <a href="https://colab.research.google.com/github/hussienfci/Data_Science/blob/main/Drugs_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_excel('/content/medicine_dataset.xlsx')
df
# Out:
#                                         name  \
# 0                   augmentin 625 duo tablet
# 1                        azithral 500 tablet
# 2                           ascoril ls syrup
# 3                       allegra 120mg tablet
# 4                             avil 25 tablet
# ...                                      ...
# 248213  zestrain 100mg/325mg/250mg tablet mr
# 248214              zoxinace 200mg tablet sr
# 248215                     zivex 25mg tablet
# 248216               zi fast 500mg injection
# 248217             zyvocol 1% dusting powder
#
#                                 substitute0             substitute1  \
# 0            Penciclav 500 mg/125 mg Tablet  Moxikind-CV 625 Tablet
# 1                   Zithrocare 500mg Tablet         Azax 500 Tablet
# 2                           Solvin LS Syrup       Ambrodil-LX Syrup
# 3                              Lcfex Tablet     Etofex 120mg Tablet
# 4                        Eralet 25mg Tablet                     NaN
# ...

# %%
df_cleaned = df.dropna() ;
df_cleaned
# Out:
#                                         name  \
# 0                   augmentin 625 duo tablet
# 1                        azithral 500 tablet
# 2                           ascoril ls syrup
# 3                       allegra 120mg tablet
# 5                           allegra-m tablet
# ...                                      ...
# 248213  zestrain 100mg/325mg/250mg tablet mr
# 248214              zoxinace 200mg tablet sr
# 248215                     zivex 25mg tablet
# 248216               zi fast 500mg injection
# 248217             zyvocol 1% dusting powder
#
#                                 substitute0             substitute1  \
# 0            Penciclav 500 mg/125 mg Tablet  Moxikind-CV 625 Tablet
# 1                   Zithrocare 500mg Tablet         Azax 500 Tablet
# 2                           Solvin LS Syrup       Ambrodil-LX Syrup
# 3                              Lcfex Tablet     Etofex 120mg Tablet
# 5                        Emlukast-FX Tablet       LCFEX-Mont Tablet
# ...

# %%
df_cleaned.to_excel('medicine_v2_0.xlsx', index= False) ;

# %%
df_cleaned.isna().sum()
# Out:
# name                 0
# substitute0          0
# substitute1          0
# substitute2          0
# substitute3          0
# substitute4          0
# use0                 0
# Therapeutic Class    0
# dtype: int64

# %%
df_cleaned.drop(df_cleaned.index[-151000:], inplace=True)
df_cleaned
# Out:
# /tmp/ipython-input-811990766.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned.drop(df_cleaned.index[-151000:], inplace=True)
#                                    name                        substitute0  \
# 0              augmentin 625 duo tablet     Penciclav 500 mg/125 mg Tablet
# 1                   azithral 500 tablet            Zithrocare 500mg Tablet
# 2                      ascoril ls syrup                    Solvin LS Syrup
# 3                  allegra 120mg tablet                       Lcfex Tablet
# 5                      allegra-m tablet                 Emlukast-FX Tablet
# ...                                 ...                                ...
# 80704                 dcortz 6mg tablet                   Zefcort 6 Tablet
# ...

# %%
df_cleaned.to_excel('medicine_v11_0.xlsx', index= False) ;
